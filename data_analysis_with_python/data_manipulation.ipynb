# %%
import pandas as pd

# %%
# https://github.com/krishnaik06/Complete-Data-Science-With-Machine-Learning-And-NLP-2024/blob/main/3-Complete%20Linear%20Regression/Regression%20Handwritten%20Notes/1-Simple%20Linear%20Regression.pdf

# %%
pd.read_csv('data_analysis_with_python/Online Sales Data.csv')
